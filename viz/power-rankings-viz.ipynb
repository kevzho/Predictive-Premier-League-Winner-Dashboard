# %% [markdown]
# # Power Rankings Visualiation - Checking for disparities between actual table & rankings

# %%
#libs
from IPython.display import display, HTML
import pandas as pd

# %%
power_ranking_df = pd.read_csv(r'../data/power_rankings_2526.csv')
prem_table_df = pd.read_csv(r'../data/summary_table2526.csv')

display(HTML(f"""
<div style="display: flex; gap: 50px;">
    <div>{power_ranking_df.to_html(index=False)}</div>
    <div>{prem_table_df.to_html(index=False)}</div>
</div>
"""))
# Out:
# <div style="display: flex; gap: 50px;">
#     <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Team</th>
#       <th>EloRating</th>
#       <th>Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Arsenal</td>
#       <td>1620.8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Man City</td>
#       <td>1583.1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Man United</td>
#       <td>1565.4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Aston Villa</td>
#       <td>1548.2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Liverpool</td>
#       <td>1533.6</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>Chelsea</td>
#       <td>1521.7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>Brentford</td>
#       <td>1518.0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Brighton</td>
#       <td>1516.3</td>
#       <td>8</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# As you can see, there actually are some disparities between the actual premier league table and simulated ELO.
