# %% [markdown]
# # Visualizing Raw Premier League Data

# %% [markdown]
# The source for this first piece of data: https://www.football-data.co.uk/englandm.php

# %%
import pandas as pd

df = pd.read_csv(r'../data/RAW_2526.csv')
df
# Out:
#     7Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0     E0  15/08/2025  20:00    Liverpool     Bournemouth     4     2   H
# 1     E0  16/08/2025  12:30  Aston Villa       Newcastle     0     0   D
# 2     E0  16/08/2025  15:00     Brighton          Fulham     1     1   D
# 3     E0  16/08/2025  15:00   Sunderland        West Ham     3     0   H
# 4     E0  16/08/2025  15:00    Tottenham         Burnley     3     0   H
# ..   ...         ...    ...          ...             ...   ...   ...  ..
# 145   E0  06/12/2025  15:00    Tottenham       Brentford     2     0   H
# 146   E0  06/12/2025  17:30        Leeds       Liverpool     3     3   D
# 147   E0  07/12/2025  14:00     Brighton        West Ham     1     1   D
# 148   E0  07/12/2025  16:30       Fulham  Crystal Palace     1     2   A
# 149   E0  08/12/2025  20:00       Wolves      Man United     1     4   A
#
#      HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# ...
